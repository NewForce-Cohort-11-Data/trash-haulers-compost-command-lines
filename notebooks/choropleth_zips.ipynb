# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

# %%
zipcodes = gpd.read_file('../data/zipcodes.geojson')
print(zipcodes.crs)
zipcodes.info()
# Out:
# EPSG:4326
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   zip             56 non-null     object
#  1   objectid        56 non-null     object
#  2   po_name         56 non-null     object
#  3   shape_stlength  56 non-null     object
#  4   shape_starea    56 non-null     object
#  5   geometry        56 non-null     geometry
# dtypes: geometry(1), object(5)
# memory usage: 2.8+ KB

# %%
zipcodes
# Out:
#       zip objectid         po_name      shape_stlength        shape_starea  \
# 0   37115        1         MADISON  178783.02488886821  596553400.57885742
# 1   37216        3       NASHVILLE  75820.997821400058  188884682.28344727
# 2   37204        9       NASHVILLE  93180.292250425613  200664795.51708984
# 3   37027       11       BRENTWOOD   159760.6942933173  174978422.04101562
# 4   37064       18        FRANKLIN  28995.828320601937  46969608.005737305
# 5   37143       23          PEGRAM  7047.8267580476522   1900364.756652832
# 6   37080       42         JOELTON  2319.8074237329579  56522.611450195313
# 7   37221       17       NASHVILLE   241372.3112694624  1266395059.4877319
# 8   37072       47  GOODLETTSVILLE  225242.45424953851  1094968706.7701416
# 9   37212       54       NASHVILLE  58759.243654332378  73920091.147705078
# 10  37135        7     NOLENSVILLE   69742.56063023665  74707266.403198242
# ...

# %%
zipcodes.plot()
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10,10))
zipcodes.plot(ax = ax)
ax.axis('off');

# %%
fines = pd.read_csv('../data/fines.csv')

fines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10917 entries, 0 to 10916
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Incident Address  10917 non-null  object
#  1   Missed Count      10917 non-null  int64
#  2   Fines             10917 non-null  int64
#  3   Zip Code          10880 non-null  float64
#  4   Trash Hauler      10587 non-null  object
#  5   Trash Route       10582 non-null  object
#  6   Council District  10893 non-null  float64
#  7   State Plan X      10906 non-null  float64
#  8   State Plan Y      10906 non-null  float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 767.7+ KB

# %%
fines_lean = fines.drop(columns = ['Incident Address', 'Trash Hauler', 'Trash Route', 'State Plan X', 'State Plan Y', 'Council District'])
fines_lean['Zip Code'] = fines_lean['Zip Code'].astype('Int64').astype(object)
fines_lean
# Out:
#        Missed Count  Fines Zip Code
# 0                25   4800    37203
# 1                21   4000    37013
# 2                20   3800    37013
# 3                20   3800    37209
# 4                19   3600    37205
# ...             ...    ...      ...
# 10912             1      0    37013
# 10913             1      0    37205
# 10914             1      0    37212
# 10915             1      0    37208
# 10916             1      0    37218
#
# [10917 rows x 3 columns]

# %%
fines_by_zip = fines_lean.groupby('Zip Code').sum().sort_values('Fines', ascending=False).reset_index()

# %%
fines_by_zip['Zip Code'] = fines_by_zip['Zip Code'].astype('object')
fines_by_zip
# Out:
#    Zip Code  Missed Count   Fines
# 0     37013          2048  149600
# 1     37211          1896  127000
# 2     37215          1240   95800
# 3     37205          1093   85400
# 4     37209          1153   82200
# 5     37115          1053   79800
# 6     37207          1023   69400
# 7     37218           829   62400
# 8     37208           856   62000
# 9     37206          1025   59400
# 10    37214           826   46600
# 11    37217           693   43000
# 12    37204           533   40000
# 13    37216           674   35600
# 14    37210           437   33400
# 15    37212           489   31800
# 16    37203           330   29200
# 17    37220           240   16400
# 18    37027           134    8200
# 19    37189            56    5200
# 20    37221            45    3800
# 21    37201            30    3200
# 22    37219            28    3000
# 23    37086             3     200
# 24    37138             3       0
# 25    37076             4       0
# ...

# %%
fines_by_zip.columns = fines_by_zip.columns.str.strip()

# %%
zipcodes.columns = zipcodes.columns.str.strip()

# %%
print(zipcodes['zip'].dtype)
print(fines_by_zip['Zip Code'].dtype)
# Out:
# object
# object

# %%
zipcodes['zip'] = zipcodes['zip'].astype(str).str.zfill(5)  # ensures '00501' not '501'
fines_by_zip['Zip Code'] = fines_by_zip['Zip Code'].astype(str).str.zfill(5)

# %%
zips_with_fines = pd.merge(left = zipcodes, right = fines_by_zip, 
                    left_on = 'zip', right_on = 'Zip Code', how='left')
zips_with_fines
# Out:
#       zip objectid         po_name      shape_stlength        shape_starea  \
# 0   37115        1         MADISON  178783.02488886821  596553400.57885742
# 1   37216        3       NASHVILLE  75820.997821400058  188884682.28344727
# 2   37204        9       NASHVILLE  93180.292250425613  200664795.51708984
# 3   37027       11       BRENTWOOD   159760.6942933173  174978422.04101562
# 4   37064       18        FRANKLIN  28995.828320601937  46969608.005737305
# 5   37143       23          PEGRAM  7047.8267580476522   1900364.756652832
# 6   37080       42         JOELTON  2319.8074237329579  56522.611450195313
# 7   37221       17       NASHVILLE   241372.3112694624  1266395059.4877319
# 8   37072       47  GOODLETTSVILLE  225242.45424953851  1094968706.7701416
# 9   37212       54       NASHVILLE  58759.243654332378  73920091.147705078
# 10  37135        7     NOLENSVILLE   69742.56063023665  74707266.403198242
# ...

# %%
zips_with_fines = zips_with_fines.drop(columns = 'Zip Code')

# %%
zips_with_fines = zips_with_fines.fillna(0)

# %%
zips_with_fines['Missed Count'] = zips_with_fines['Missed Count'].astype('Int64')

# %%
zips_with_fines['Fines'] = zips_with_fines['Fines'].astype('Int64')

# %%
zips_with_fines
# Out:
#       zip objectid         po_name      shape_stlength        shape_starea  \
# 0   37115        1         MADISON  178783.02488886821  596553400.57885742
# 1   37216        3       NASHVILLE  75820.997821400058  188884682.28344727
# 2   37204        9       NASHVILLE  93180.292250425613  200664795.51708984
# 3   37027       11       BRENTWOOD   159760.6942933173  174978422.04101562
# 4   37064       18        FRANKLIN  28995.828320601937  46969608.005737305
# 5   37143       23          PEGRAM  7047.8267580476522   1900364.756652832
# 6   37080       42         JOELTON  2319.8074237329579  56522.611450195313
# 7   37221       17       NASHVILLE   241372.3112694624  1266395059.4877319
# 8   37072       47  GOODLETTSVILLE  225242.45424953851  1094968706.7701416
# 9   37212       54       NASHVILLE  58759.243654332378  73920091.147705078
# 10  37135        7     NOLENSVILLE   69742.56063023665  74707266.403198242
# ...

# %%
fig, ax = plt.subplots(figsize=(10,10))
zips_with_fines.plot(
    column = 'Fines',
    cmap = 'Reds', 
    legend = True,
    edgecolor = 'black', 
    ax = ax)
plt.title('Fine Totals by Zip Code')
ax.axis('off');
plt.savefig('../visualizations/fines_map.png')

# %%
fig, ax = plt.subplots(figsize=(10,10))
zips_with_fines.plot(
    column = 'Missed Count',
    cmap = 'Greys', 
    legend = True,
    edgecolor = 'black', 
    ax = ax)
    
plt.title('Missed Trash Pickups by Zip Code')

ax.axis('off');

plt.savefig('../visualizations/missed_trash_map.png')
